# %%
import pandas as pd

# %%
 file = "../Resources/Cities_weather.csv"

weather_df = pd.read_csv(file)
weather_df.head()
# Out:
#    Unnamed: 0        City      Lat       Lng  Temperature  Humidity  \
# 0           0  codrington -38.2667  141.9667        10.79      68.0
# 1           1      utiroa      NaN       NaN          NaN       NaN
# 2           2   sept-iles  50.2001  -66.3821         8.92      77.0
# 3           3    takoradi   4.8845   -1.7554        24.77      86.0
# 4           4    zhicheng  30.2956  111.5047        30.80      48.0
#
#    Cloudiness  Wind Speed Country
# 0       100.0        4.54      AU
# 1         NaN         NaN     NaN
# 2       100.0        5.36      CA
# 3       100.0        1.60      GH
# 4         1.0        2.04      CN

# %%
weather_df = weather_df.rename(columns = {"Unnamed: 0":"City_ID"})
weather_df = weather_df.dropna()
weather_df.set_index("City_ID", inplace = True)
weather_df.head()
# Out:
#                City      Lat       Lng  Temperature  Humidity  Cloudiness  \
# City_ID
# 0        codrington -38.2667  141.9667        10.79      68.0       100.0
# 2         sept-iles  50.2001  -66.3821         8.92      77.0       100.0
# 3          takoradi   4.8845   -1.7554        24.77      86.0       100.0
# 4          zhicheng  30.2956  111.5047        30.80      48.0         1.0
# 5         kavaratti  10.5669   72.6420        27.52      80.0       100.0
#
#          Wind Speed Country
# City_ID
# 0              4.54      AU
# 2              5.36      CA
# 3              1.60      GH
# 4              2.04      CN
# 5              8.02      IN

# %%
html = weather_df.to_html(classes=["table-bordered", "table-striped", "table-hover"])

# %%
print(html)
# Out:
# <table border="1" class="dataframe table-bordered table-striped table-hover">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Temperature</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#     </tr>
#     <tr>
#       <th>City_ID</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>codrington</td>
#       <td>-38.2667</td>
#       <td>141.9667</td>
#       <td>10.79</td>
#       <td>68.0</td>
#       <td>100.0</td>
#       <td>4.54</td>
#       <td>AU</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>sept-iles</td>
#       <td>50.2001</td>
#       <td>-66.3821</td>
#       <td>8.92</td>
#       <td>77.0</td>
#       <td>100.0</td>
# ...
